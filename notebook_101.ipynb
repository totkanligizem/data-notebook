# %%
print("Jupyter çalışıyor 🚀")
# Out:
# Jupyter çalışıyor 🚀

# %% [markdown]
# # Notebook 101
#
# İlk notebook’una hoş geldin! Eğer bu senin ilk notebook’un değilse bile lütfen okumaya devam et; muhtemelen henüz bilmediğin birkaç ipucu/kısayol öğrenebilirsin!
#
# ## Jupyter Notebook nedir?
#
# Notebook, hem kod (örneğin Python) hem de zengin metin öğeleri (paragraflar, denklemler, şekiller, linkler vb.) içeren bir dokümandır; bu zengin içerik Markdown [Markdown](https://guides.github.com/features/mastering-markdown/) ve MathJax [MathJax](https://www.mathjax.org/) sayesinde mümkün olur.
#
# Jupyter Notebook üç bileşeni bir araya getirir:
#
# 1. **Notebook web uygulaması**:Kod yazmak ve çalıştırmak, ayrıca notebook dokümanları oluşturmak için kullanılan etkileşimli bir web uygulamasıdır.
# 2. **Kernel’ler** :Notebook web uygulaması tarafından başlatılan ve kullanıcının kodunu belirli bir dilde çalıştırıp çıktıyı tekrar notebook web uygulamasına geri gönderen ayrı process’lerdir. Kernel aynı zamanda interactive widget’lar için yapılan hesaplamalar, tab tamamlama (tab completion) ve introspection gibi işleri de yürütür.
# 3. **Notebook dokümanları**: Notebook web uygulamasında gördüğün tüm içeriğin bir temsilini içinde barındıran, kendi kendine yeterli dokümanlardır; hesaplamaların input ve output’ları, açıklayıcı metinler, denklemler, görseller ve objelerin zengin medya gösterimleri buna dahildir. Her notebook dokümanının kendi kernel’i vardır.
#
# ## Kernels
#
# Jupyter’ın kernel ve messaging mimarisi sayesinde Notebook, birçok farklı programlama dilinde kod çalıştırabilir. Bir kullanıcı bir notebook dokümanı açtığında, web uygulaması o notebook için kodu çalıştıracak bir kernel başlatır. Her kernel tek bir programlama dilinde kod çalıştırabilir ve şu diller için mevcut kernel’ler vardır:
#
# - [Python](https://github.com/ipython/ipython)
# - [Julia](https://github.com/JuliaLang/IJulia.jl)
# - [R](https://github.com/IRkernel/IRkernel)
# - [Ruby](https://github.com/sciruby/iruby)
#
# Varsayılan kernel Python’dur. Notebook, kullanıcıların hangi notebook’un hangi kernel ile çalışacağını kolayca seçmesini sağlar.
#
# Bu kernel’lerin her biri, notebook web uygulaması ve web tarayıcısı ile JSON tabanlı bir protokol üzerinden ZeroMQ/WebSockets kullanarak iletişim kurar. Bu protokolün detayları burada [here](https://jupyter-client.readthedocs.io/en/stable/messaging.html) açıklanmıştır. Kullanıcıların çoğunun bu ayrıntıları bilmesine gerek yoktur; ama “kernel’ler kodu çalıştırır” mantığını anlamak önemlidir.
#
#
# Eğer bilgisayarında hangi kernel’lerin yüklü olduğunu hatırlamıyorsan, terminalde şu komutu çalıştırabilirsin:
#
# ```bash
# jupyter kernelspec list
# ```
#
# ---
#
# 💡 Şimdi **ilk hilemizi** öğrenelim: Notebook içinde doğrudan bash komutları çalıştırılabilir!
# Bir kod hücresinin başına ! koyman yeterli. Örneğin, aşağıdaki hücreyi çalıştır:

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    /Users/gizemtotkanli/.pyenv/versions/3.12.9/envs/workintech_current/share/jupyter/kernels/python3

# %% [markdown]
# Başka bir komutla deneyelim; örneğin Kernel’in şu anda hangi dizinde olduğunu kontrol edelim:

# %%
# !pwd
# Out:
# /Users/gizemtotkanli/code/data-notebook

# %% [markdown]
# Bu konu ve %%bash tekniği hakkında daha fazla bilgiyi dokümantasyonda
#  bulabilirsin.[documentation](https://ipython.readthedocs.io/en/stable/interactive/python-ipython-diff.html#shell-assignment)
#
# ---

# %% [markdown]
# ## Belgeler
#
# Notebook belgeleri, çalıştırılabilir bir oturumun giriş ve çıkışlarını içerir; ayrıca koda eşlik eden fakat yürütülmesi amaçlanmayan açıklayıcı metinleri de barındırır. Kod çalıştırıldığında oluşan zengin çıktılar—HTML, görseller, videolar ve grafikler—doğrudan notebook içine gömülür. Bu da notebook’u bir hesaplamanın tam ve kendi içinde yeterli bir kaydı hâline getirir.
#
# Notebook web uygulamasını bilgisayarında çalıştırdığında, notebook belgeleri yerel dosya sisteminde .ipynb uzantılı dosyalardır. Böylece bu dosyaları klasörlere ayırma, düzenleme ve başkalarıyla paylaşma gibi alışık olduğun iş akışlarını kullanabilirsin.
#
# <details>
#
#   <summary markdown="span">
#   Why <code>.ipynb</code>❓ (I'm a detail, click me to open me.)
#   </summary>
#
#   `ipynb` comes from "IPython Notebook", the original name of Jupyter Notebook.
#
# </details>
#
# Yukarıdaki detayı gördün mü? Böyle açılır kutuları bu challenge noteboklarında sık sık göreceksin. Açtığında detaylar, ipuçları ve hatta çözümler bile bulacaksın. Bu yüzden gözün açık olsun!
#
# Notebook’lar lineer bir hücre dizisinden oluşur. Üç temel hücre tipi vardır:
#
# 1. **Code** hücreleri: Kernel’de çalıştırılan canlı kodun girdi ve çıktıları
# 2. **Markdown** hücreleri: Açıklayıcı metinler ve içine gömülü LaTeX denklemleri
# 3. **Raw** hücreleri: Notebook farklı formatlara dönüştürüldüğünde (nbconvert ile) olduğu gibi eklenen, düzenlenmeyen ham metinler.
#
# Notebook belgeleri dahili olarak bir [JSON](https://en.wikipedia.org/wiki/JSON). yapısıdır. Bu sayede herhangi bir programlama dili tarafından okunabilir ve programatik olarak manipüle edilebilir. JSON bir metin formatı olduğundan, notebook’lar sürüm kontrolü (Git gibi) için de uygundur.
#
# Notebook’lar Jupyter’in nbconvert aracıyla HTML, reStructuredText, LaTeX, PDF ve sunum (reveal.js) gibi pek çok statik formata dönüştürülebilir (bootcamp’teki slaytlar da bu şekilde oluşturuluyor).
#
# ---
#
# ❓Sıra sende: Aşağıdaki hücreye biraz markdown ekle.
# Bir alt başlık, biraz kalın yazı, ve bir link eklemeyi dene!
#
# # Notebook 101
#
# > Spoiler: Bu **ilk markdown denemem değil**
#
# > Ama yine de “gösteriş” serbest.
#
# ## Deneme
#
# - **Kalın** yazı
# - *İtalik* yazı
# - `inline code`
#
#
# ### Link ve vurgu
#
# **GitHub Profilim:** [totkanligizem](https://github.com/totkanligizem)
#
# <span style="color:#ffcc00; font-weight:700;">Renkli vurgu (HTML ile)</span>
# <span style="color:#7aa2f7;"><em>İtalik + renk</em></span>
#
# Hedef: *Markdown kaslarını ısıtmak.*

# %% [markdown]
# ***TODO - Düzenleme moduna girmek için çift tıkla. Ardından buraya biraz markdown yaz. Sonucu önizlemek için hücreyi çalıştır. Düzenleme moduna yeniden girmek için tekrar çift tıkla.

# %% [markdown]
# ❓ Aşağıdaki hücreye biraz Python kodu yaz. Örneğin "Hello from Jupyter" yazdırarak (print) başlayabilirsin. Sonucu görmek için hücreyi çalıştır.

# %%
# TODO: biraz Python kodu yaz

print("Hello from Jupyter")
# Out:
# Hello from Jupyter

# %% [markdown]
# ---
#
# ## Editor

# %% [markdown]
# Jupyter Notebook modlu (modal) bir kullanıcı arayüzüne sahiptir. Bu, klavyenin işlevinin Notebook’un hangi modda olduğuna bağlı olarak değiştiği anlamına gelir. İki mod vardır: edit (düzenleme) modu ve command (komut) modu.
#
# ### Edit mode (Düzenleme Modu)
#
# Edit mode, hücre giriş düzenleme alanının etrafındaki mavi dar bir çerçeve ve yanıp sönen imleç ile belirtilir (ince yanıp sönen dikey çizgi):
#
# ![Cell in edit mode with tight border](https://wagon-public-datasets.s3.amazonaws.com/data-science-images/02-Data-Toolkit/01-Data-Analysis/jupyter-edit-mode.png)
#
# Bir hücre edit modundayken, hücreye normal bir metin düzenleyici gibi yazabilirsiniz.
#
# Edit moduna girmek için `Enter` tuşuna basın veya fareyle hücrenin düzenleme alanına tıklayın.
#
# ### Command mode (Komut modu)
#
# Command mode, hücrenin tamamının etrafındaki daha geniş bir mavi çerçeve ile belirtilir:
#
# ![Cell in command mode with border further away](https://wagon-public-datasets.s3.amazonaws.com/data-science-images/02-Data-Toolkit/01-Data-Analysis/jupyter-command-mode.png)
#
# Komut modundayken, hücrelerin içeriğine yazamazsınız; bunun yerine notebook’un bütününü düzenleyebilirsiniz. Bu modda klavye, hücre ve notebook işlemlerini hızlıca yapabilmenizi sağlayan kısayollarla eşleştirilmiştir. Örneğin, komut modundayken C tuşuna basarsanız geçerli hücreyi kopyalarsınız.
#
# Komut modundayken hücre içine yazmaya çalışmayın: beklenmedik şeyler olabilir!
#
# Komut moduna girmek için Esc tuşuna basın veya fareyle hücrenin düzenleme alanının dışına tıklayın.

# %% [markdown]
# ## Klavye Kısayolları
#
# Klavye kısayollarını öğrenmek, herhangi bir notebook’u daha hızlı yönetebilmek için çok önemlidir. İstediğiniz anda tüm kısayolları içeren bir pencere açmak için araç çubuğundaki Help menüsüne, ardından Keyboard Shortcuts seçeneğine tıklayabilirsiniz. Ayrıca komut modundayken klavyenizde H tuşuna basabilirsiniz.
#
# Bugün öğrenmeye başlamanızı önerdiğimiz birkaç kısayol:
#
# **Command** (komut) modundayken:
# - `A` Geçerli hücrenin üstüne **Above** bir hücre ekler
# - `B` Geçerli hücrenin altına **Below** bir hücre ekler
# - `D`, `D` (iki kez `D` ) Geçerli hücreyi siler. Kurtarmak için `Edit` > `Undo Delete Cells`
# - `Y` Geçerli hücre türünü **Code** (Python) yapar
# - `M` Geçerli hücre türünü **Markdown** yapar
# - `↩` ((`Enter` ) veya çift tıklama ) **edit**  moduna girer
# - `↑`/`↓` ((Yukarı / Aşağı ok) `Up`/`Down` ) Hücreler arasında gezinir
#
#  **edit** modundayken:
#
# - `Esc` Komut moduna geçer (yani edit modundan çıkar)
# - `Ctrl`-`↩` ( `Ctrl` `Enter`) Kodu çalıştırır ve aynı hücrede komut moduna geçer
# - `⇧`-`↩` ( `Shift` `Enter`) Kodu çalıştırır, altına yeni bir hücre oluşturur ve o yeni hücrede edit moduna girer

# %% [markdown]
# ---
#
# ❓ Aşağıdaki alanda klavye kısayollarını pratik et:

# %% [markdown]
# ---
#
# ## Notebook dışından _outside_ kod çalıştırmak
# Şu ana kadar Python kodunu özel `*.py` dosyalarına yazmayı öğrendin. Bugünden itibaren Python kodunu çoğunlukla doğrudan notebook** içinde çalıştıracağız.
#
# MLOps modülünde, bir modeli production ortamına nasıl deploy edeceğimizi öğreneceğiz; bu da Notebook’tan çıkıp tekrar klasik  `*.py` dosyalarına dönmek demek.
#
# Şu anda bilmen gereken şey şu, Python kodunu dış dosyalara yazmaya devam edip, o kodu Notebook içinden çağırabilirsin (**call that code from the Notebook**).
#
# ---
#
# ❓Bir örnek yapalım. Terminaline geri dön, yeni bir sekme aç, Workintech’teki talimatlarla bu challenge klasörüne `cd` ile gir ve `code .` komutuyla projeyi VS Code’da aç. İçeride `hello.py` dosyasını bulacaksın. İçine `"Hello from hello.py"` döndüren bir hello_world function’ı yaz.
#
# Ardından aşağıdaki hücreyi çalıştır (  `autoreload` özelliğini ilerideki challenge’larda daha detaylı öğreneceğiz ):

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Şimdi, `hello.py` dosyasından `hello_world()` function’ını içe aktardığımız ve ardından bu içe aktarılan function’ı kullandığımız bu hücreyi çalıştır.

# %%
from hello import hello_world

sentence = hello_world()

# %% [markdown]
# Eğer `hello_world()` fonksiyonunu doğru şekilde kodladıysan, hiçbir şey görüntülenmemiş olmalı. Eğer bir mesaj görüntüleniyorsa, muhtemelen bir değer döndürmek (**returning** ) yerine ekrana bir şey yazdırmışsındır (print).

# %% [markdown]
# Şimdi aşağıdaki hücreyi çalıştır. Ekranda şu yazıyı göstermeli: "`'Hello from hello.py'`". Eğer bunu göstermiyorsa, function’ından bir şey return etmeyi unuttun demektir. Bu durumda: function’ını düzelt, tekrar import et (yukarıdaki kod hücresini yeniden çalıştır), ardından aşağıdaki hücreyi tekrar çalıştır.

# %%
sentence
# Out:
# 'Hello from hello.py'

# %% [markdown]
# Artık kodunun hatasız çalıştığını ve yapması gerekeni yaptığını bildiğine göre, tanımladığımız testleri çalıştırma zamanı geldi.
#
# Aşağıdaki hücreleri çalıştırarak kodunu test et.

# %% [markdown]
# ### Kodunu Test Et!

# %%
from nbresult import ChallengeResult

result = ChallengeResult('import_hello',
    sentence=sentence
)
result.write()

# %%
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/gizemtotkanli/.pyenv/versions/3.12.9/envs/workintech_current/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/gizemtotkanli/code/data-notebook/tests
# plugins: anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 2 items
#
# test_import_hello.py::TestImportHello::test_method_returns_a_string PASSED [ 50%]
# test_import_hello.py::TestImportHello::test_method_returns_correct_sentence PASSED [100%]
#
# ============================== 2 passed in 0.00s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/import_hello.pickle
#
# git commit -m 'Completed import_hello step'
#
# git push origin master

# %% [markdown]
# ‼️Workintech üzerindeki durumunu kontrol et. Bu aşamada 3 üzerinden 2’ye ulaşmış olmalısın. Şu ana kadar sadece yukarıdaki iki testin sonucunu commit edip pushladın. Bu testler notebook içindeki sonuçları kontrol ediyordu, ancak `.py` dosyanı doğrudan test eden üçüncü bir test daha var.
#
# O test şu anda başarısız çünkü gerçekten önemli olan şeyler — yani kodun ve notebook’un — henüz commit edilip pushlanmadı!

# %% [markdown]
# ---
#
# ## Ayrılmadan önce...
#
# Notebook’unu kaydet, terminale geri dön ve aşağıdaki komutu çalıştırarak hem yukarıda çalıştırdığın testi hem de diğer tüm testleri çalıştır:
#
# ```bash
# make
# ```
#
# Bu komut hem notebook hem de `py` dosyaları için testleri çalıştıracak. 3 testin 3’ünü de geçmelisin.
#
# Ardından ilerlemeni kaydet!
#
#
# ```bash
# git add notebook_101.ipynb hello.py
# git commit -m "Completed the Notebook 101 tutorial"
# git push origin master
# ```
#
# Şimdi Workintech'te durumunu tekrar kontrol et. Artık 3 üzerinden 3’e ulaşmış olmalısın.
#
# ‼️ Notebook içeren her challenge’da, test sonuçlarını (`.pickle` dosyaları) **ve** notebook’larını (`.ipybn` dosyaları) commit etmeyi unutma!

# %% [markdown]
# ---
#
# ## [Opsiyonal] Matematik
#
# Jupyter Notebook’un içindeki Markdown işleyicisi MathJax (**MathJax-aware**) desteklidir. Bu da MathJax’in Tex ve LaTeX alt kümesini kullanarak matematiksel ifadeleri özgürce yazabileceğin anlamına gelir.
#
# Bir cümlenin içine matematiksel ifade eklemek için `$`kullanabilirsin. Örneğin,  `$\sqrt{3x-1}+(1+x)^2$` şu şekilde görüntülenir: $\sqrt{3x-1}+(1+x)^2$.
#
# Aşağıdaki Markdown hücrelerini çalıştırmayı dene ve sonucu keyifle izle! (Source: [Motivating Examples - Jupyter Notebook](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html))

# %% [markdown]
# ### (`n`) madeni para atıldığında (`k`) kez tura gelme olasılığı

# %% [markdown]
# \begin{equation*}
# P(E) = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}

# %% [markdown]
# ### Fizikte Maxwell Denklemleri

# %% [markdown]
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\   \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
